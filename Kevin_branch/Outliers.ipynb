# %%
uk_drugs = drugs.query("Country == 'UK'")

# %%
personality_traits = uk_drugs.iloc[:, 7:14]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-88bd9f995dbe> in <module>
# ----> 1 personality_traits = uk_drugs.iloc[:, 7:14]
#
# NameError: name 'uk_drugs' is not defined

# %%
def plot_box_numeric(df, ncols=7, nrows=2, figsize=(20, 10)):

    
    #if len(df_num.columns) > ncols*nrows:
        #raise "Change ncols and nrows. Too many variables for this size"
    
    fig, axs = plt.subplots(ncols=ncols, nrows=nrows, figsize=figsize)
    index = 0
    axs = axs.flatten()
    for k,v in df.items():
        sns.boxplot(y=k, data=df, ax=axs[index])
        index += 1
    plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)

# %%
plot_box_numeric(personality_traits, ncols=3, nrows=3, figsize=(20, 20) )
